# %% [markdown]
# ФИО Сметанин Георгий Михайлович

# %%
Сметанин Георгий Михайлович

# %% [markdown]
# **Во всей практике нельзя применять библиотеки предоставляющие готовые решения!**

# %% [markdown]
# # **Задача 1.**

# %% [markdown]
# Типы данных Напишите программу на Python, которая принимает список чисел в качестве входных данных от пользователя, а затем выводит сумму, среднее значение и максимальное значение из списка.
#
# ***Нельзя использовать: len(), min(), max(), average(), sum()***
#
# Ввод:
# ```
# 1 2 3 4 5 6 7
# ```
# Вывод:
#
# ```
# Сумма чисел: 28
# Среднее арифм.: 4.0
# Максимальное значение: 7
# ```

# %%
numbers = input()
space = numbers.count(' ')
numbers = numbers.split()
x = 0
sum = 0
max = 0
for i in range(1, space+2):
  if max > int(numbers[x]):
    max = max
  else:
    max = int(numbers[x])
  sum = int(numbers[x]) + sum
  x = x+1
print('Сумма чисел: ' + str(sum))
sred = sum/(space+1)
print('Среднее арифм.: ' + str(sred))
print('Максимальное значение: ' + str(max))
# Out:
# 1 2 3 4 5 6 7
# <class 'str'>
# Сумма чисел: 28
# Среднее арифм.: 4.0
# Максимальное значение: 7

# %% [markdown]
# # **Задача 2.**

# %% [markdown]
# Напишите программу на Python, которая принимает список слов в качестве входных данных от пользователя, а затем распечатывает список в обратном порядке.
#
# Ввод:
#
# ```
# апельсин мандарин яблоко
# ```
#
# Вывод:
#
# ```
# яблоко мандарин апельсин
# ```

# %%
stroke = input()
res = []
stroke = stroke.split()
space = len(stroke)
for i in range(space-1, -1, -1):
  res.append(stroke[i])
print(*res)
# Out:
# апельсин мандарин яблоко
# яблоко мандарин апельсин

# %% [markdown]
# # **Задача 3**

# %% [markdown]
# Простой чат-бот
# Создайте простого чат-бота, который отвечает на основные запросы пользователей. Программа должна использовать условные выражения для определения намерений пользователя и последующего соответствующего ответа.
#
# Чат бот может:
#
# - помогать складывать числа
# - подсказывать фильм, музыку и тд (из заранее созданного списка)
# - создавать список дел (а также выводить его, обновлять, очищать)
#
# Интерфейс чат-бота на ваше усмотрение, это могут быть как заранее определенные команды, так и к примеру вызов команды по номеру
#
# *Реализовать без использования функций*
#
# Пример:
#
# Ввод:
#
# ```
# Олег, какую мызыку посоветуешь?
# ```
#
# Вывод:
#
# ```
# Я бы посоветовал вам: Led Zeppelin Stairway to Heaven
# ```

# %%
question = input()
if question.count('сложи') or question.count('+'):
  res = ''.join(filter(str.isdigit, question))
  res = res.split()
  print(res)
  space = len(res)
  sum = 0
  for i in range (0, space):
    res[i]= int(res[i])
    sum = sum + res[i]
  print(sum)
else:
  print('ne')
# Out:
# сложи 1 3 15
# ['1315']
# 1315

# %% [markdown]
# # **Задача 4.**

# %% [markdown]
# Камень, ножницы, бумага
#
# Создайте игру в Камень, ножницы, бумагу, в которой пользователь может играть против компьютера. Программа должна запросить выбор пользователя, а затем сгенерировать выбор компьютера. Затем программа должна определить победителя на основе правил игры.
#
# **Этап 1:**
#
# Определение победителя
#
# **Этап 2:**
#
# Игра до 3 побед
#
#
# Ввод для "Этап 1":
#
# ```
# Камень
# ```
#
# Вывод:
#
# ```
# Компьютер: Ножницы
# Игрок: Камень
# Победа: Игрок
# ```

# %%
import random

fight = ['Камень', 'Ножницы', 'Бумага']
people_win = 0
computer_win = 0
for i in range(1, 100):
  print("Раунд - " + str(i))
  print("Игрок "+str(people_win)+":"+str(computer_win)+ " Компьютер")
  if people_win == 3:
    print('Победил игрок!')
    break
  elif computer_win == 3:
    print('Победил компик!')
    break
  people = input()
  print('Игрок: ' + people)
  computer = random.choice(fight)
  print('Компьютер: ' + computer)

  if people == computer:
    print('Ничья!')
  else:
    if people == 'Камень' and computer == 'Ножницы' or people == 'Ножницы' and computer == 'Бумага' or people == 'Бумага' and computer == 'Камень':
      print("Победа: Игрок")
      people_win = people_win+1
    else:
      print("Победа: Компьютер")
      computer_win = computer_win+1
# Out:
# Раунд - 1
# Игрок 0:0 Компьютер
# Ножницы
# Игрок: Ножницы
# Компьютер: Камень
# Победа: Компьютер
# Раунд - 2
# Игрок 0:1 Компьютер
# Ножницы
# Игрок: Ножницы
# Компьютер: Бумага
# Победа: Игрок
# Раунд - 3
# Игрок 1:1 Компьютер
# Ножницы
# Игрок: Ножницы
# Компьютер: Камень
# Победа: Компьютер
# Раунд - 4
# Игрок 1:2 Компьютер
# Ножницы
# Игрок: Ножницы
# Компьютер: Бумага
# Победа: Игрок
# Раунд - 5
# Игрок 2:2 Компьютер
# Ножницы
# Игрок: Ножницы
# Компьютер: Ножницы
# Ничья!
# Раунд - 6
# Игрок 2:2 Компьютер
# Ножницы
# Игрок: Ножницы
# Компьютер: Ножницы
# Ничья!
# Раунд - 7
# Игрок 2:2 Компьютер
# Ножницы
# Игрок: Ножницы
# Компьютер: Камень
# Победа: Компьютер
# Победил компик!

# %% [markdown]
# # **Задача 5.**

# %% [markdown]
# Создайте игру "Палач" или "Виселица", в которой пользователь должен угадать слово, предлагая буквы. Программа должна выбрать случайное слово, а затем разрешить пользователю угадывать буквы. После каждого угадывания программа должна сообщать пользователю, есть ли в слове буква или нет.
#
# **Этап 1**
# Создать саму игру (игра должна иметь привлекательный интерфейс, соотвесвующий классической висилице)
#
# **Этап 2:**
# Ввести подсчет количества очков и ограничения на попытки
#
# **Этап 3:** Добавить возможность сразу угадать слово

# %% [markdown]
# # **Дополнительно: Задача 6 (для тех, кто не сделал в прошлый раз)**

# %% [markdown]
# **Цифра на определенном месте:**
#
# Последовательно записан натуральный ряд чисел.
#
# Какая цифра стоит в N позиции
#
#
# Вввод:
#
# ```
# Введите номер позиции: 1234567890
# ```
#
# Вывод:
#
# ```
# 8
# ```

# %%
print('Введите натуральный ряд чисел')
spisok = input()
print('Введите номер позиции')
spisok = spisok.split()
n_pos = int(input())
dlina = len(spisok)
if n_pos <= dlina:
  num = spisok[n_pos-1]
  print(num)
else:
  print('Такой позиции несуществует')
# Out:
# Введите натуральный ряд чисел
# 1 2 3 4 5 6 7 345 2 4
# Введите номер позиции
# 8
# 345
